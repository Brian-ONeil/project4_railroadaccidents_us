# %% [markdown]
# # Human Factor Caused Railroad Accidents in US

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
# Read in the first CSV file and keep only the column titles
df = pd.read_csv('RRD_US_2023.csv', nrows=0)

# Loop through the remaining CSV files and stack them on top of the first one
for year in range(2022, 2018, -1):
    filename = f'RRD_US_{year}.csv'
    temp_df = pd.read_csv(filename, header=0)
    df = pd.concat([df, temp_df], axis=0, ignore_index=True)

# Write the combined CSV file to disk
df.to_csv('RRD_US_combined.csv', index=False)

# %%
df.shape
# Out:
# (9922, 146)

# %%
df.sample(10)
# Out:
#      IYR IMO RAILROAD     INCDTNO  IYR2  IMO2  RR2 INCDTNO2  IYR3  IMO3  ...  \
# 9385  19   1     BNSF   HL0119125   NaN   NaN  NaN      NaN  19.0   1.0  ...
# 808   22   8       NS      146174   NaN   NaN  NaN      NaN  22.0   8.0  ...
# 431   22  12     BNSF   CA1222109   NaN   NaN  NaN      NaN  22.0  12.0  ...
# 9016  19   7     BNSF   CA0719114   NaN   NaN  NaN      NaN  19.0   7.0  ...
# 3737  21   7      CSX      198903  21.0   7.0  ATK   167720  21.0   7.0  ...
# 7299  19   2       UP   0219GP010   NaN   NaN  NaN      NaN  19.0   2.0  ...
# 7202  19   1     MBTA       19011   NaN   NaN  NaN      NaN  19.0   1.0  ...
# 7887  19   6     NOGC  OP06022019   NaN   NaN  NaN      NaN  19.0   6.0  ...
# 7061  20  12      CSX      194728   NaN   NaN  NaN      NaN  20.0  12.0  ...
# 7526  19   8       NS      135158   NaN   NaN  NaN      NaN  19.0   8.0  ...
#
#       RCL   Latitude    Longitud SIGNAL MOPERA ADJUNCT1 ADJUNCT2 ADJUNCT3  \
# 9385  0.0  39.134924  -94.586462    2.0    5.0        K      NaN      NaN
# 808   0.0  41.691317  -86.372173    1.0    1.0        J      NaN      NaN
# 431   0.0  32.878269 -117.166142    2.0    5.0        K      NaN      NaN
# 9016  0.0  34.896143 -117.067679    2.0    5.0        K      NaN      NaN
# 3737  NaN  29.745547  -81.642086    1.0    1.0      NaN      NaN      NaN
# 7299  0.0  41.452512  -96.636535    1.0    1.0        Q      NaN      NaN
# 7202  0.0  42.373587  -71.075377    2.0    5.0      NaN      NaN      NaN
# 7887  0.0  29.837911  -89.998166    2.0    3.0      NaN      NaN      NaN
# 7061    0  34.188497  -82.165093    2.0    5.0        K      NaN      NaN
# 7526  0.0  41.677360  -85.978495    2.0    5.0        K      NaN      NaN
#
#                     SUBDIV Unnamed: 145
# 9385             ST JOSEPH          NaN
# 808   CHICAGO LINE-ELKHART          NaN
# 431              SAN DIEGO          NaN
# 9016                 CAJON          NaN
# 3737               SANFORD          NaN
# 7299          COLUMBUS SUB          NaN
# 7202                  YARD          NaN
# 7887          BELLE CHASSE          NaN
# 7061                MONROE          NaN
# 7526          CHICAGO LINE          NaN
#
# [10 rows x 146 columns]

# %%
# Drop the columns with more than 50% nulls
# Calculate the percentage of null values in each column
null_percentages = df.isnull().sum() / len(df) * 100

# Get the column names where the null percentage is greater than 50%
columns_to_drop = null_percentages[null_percentages > 50].index

# Drop the columns from the dataframe
df.drop(columns_to_drop, axis=1, inplace=True)

# Write the updated dataframe to a new CSV file
df.to_csv('RRD_US_combined_cleaned.csv', index=False)

# %%
# Convert the column names to lowercase
df.columns = df.columns.str.lower()

# %%
df.shape
# Out:
# (9922, 111)

# %%
df.sample(10)
# Out:
#      iyr imo railroad    incdtno  iyr3  imo3   rr3   incdtno3 year month  ...  \
# 2322  22   5       UP  0522SX033  22.0   5.0    UP  0522SX033   22     5  ...
# 7565  19   4       NS     133643  19.0   4.0    NS     133643   19     4  ...
# 6957  20   2      KCS   20021402  20.0   2.0   KCS   20021402   20     2  ...
# 2640  21   2       UP  0221GP005  21.0   2.0    UP  0221GP005   21     2  ...
# 3144  21  11      CSX     201531  21.0  11.0   CSX     201531   21    11  ...
# 2341  22   7       UP  0722TO008  22.0   7.0    UP  0722TO008   22     7  ...
# 9607  19   8      CSX     185069  19.0   8.0   CSX     185069   19     8  ...
# 5921  20   7      KCS   20073104  20.0   7.0   KCS   20073104   20     7  ...
# 9059  19   2     BNSF  PR0219104  19.0   2.0  BNSF  PR0219104   19     2  ...
# 1531  22   2     NJTR  202202096  22.0   2.0   ATK     169780   22     2  ...
#
#                                                   narr1  \
# 2322  TRAIN MSAFW-31 WAS MAKING A PICK UP IN TAYLOR ...
# 7565  GM42 PULLING NORTH ON EAST PULLBACK WITH 41 CA...
# 6957  CREW PULLED OUT OF YARD ON EAST MAIN (YARD RES...
# 2640  CAR CMO10361 WHEELS WERE CONTAMINATED, WHICH C...
# 3144  Y19627 PULLING OUT OF 015 TRACK WAS SIDE SWIPE...
# 2341  THE YFW10R-05, HAD TWO CARS DERAIL ON THE 17-2...
# 9607  AFTER EMPLOYEES LEFT CARS IN THE FOUL IN B30 T...
# 5921  CREW PULLING OFF INTERNATIONAL BRIDGE (WITH YA...
# 9059  C-BTMSLP0-25 IMPACTED THE C-NAMJOJ0-11 WHILE T...
# 1531  TRAIN #3248 LOCATED NEAR THE WEST END OF LINE ...
#
#                                                   narr2  \
# 2322  HIGHER THAN PRESCRIBED, CAUSING A ONE-WHEEL DE...
# 7565  TO A BYPASS COUPLING OF TILX 290206 AND ADMX 6...
# 6957  WAS LINED FOR MOVEMENT.  TRAIN RAN THRU CROSSO...
# 2640  CONSEQUENTLY, THE CAR CAUGHT UP AND COLLIDED W...
# 3144  AGE AND 1 CAR TO DERAIL.  INVESTIGATION REVEAL...
# 2341  HEAD 5 CARS TRAVERSED OVER THE SWITCH AND THE ...
# 9607                 TRIKING THE CARS LEFT IN THE FOUL.
# 5921                                     DO SUBDIVISION
# 9059  ITH RESTRICTED SPEED IN CONNECTION WITH A REST...
# 1531  Y AND THEN RIPPED OFF ENGINE #4600 AS A RESULT...
#
#                                                   narr3  rcl   latitude  \
# 2322                                                NaN  0.0  30.566067
# 7565  STRIKING EQUIPMENT IN FT03, FT04, ANF FT05. TH...  0.0  32.813658
# 6957                 OF 2 CARS.  MP 338.10 HEAVENER SUB    0  34.888449
# 2640                                                NaN    0  41.146542
# 3144                                                NaN    0  39.759791
# 2341  RSING TOWARD 19 TRACK. IT WAS FOUND THERE WAS ...  1.0  32.721540
# 9607                                                NaN  1.0  39.124551
# 5921                                                NaN    0  27.509486
# 9059  OTAL OF 3 LOCOMOTIVES AND 5 RAILCARS DERAILED....  0.0  42.347817
# 1531                                                NaN  0.0  40.750600
#
#         longitud signal mopera adjunct1                subdiv
# 2322  -97.431762    1.0    1.0        D            AUSTIN SUB
# 7565  -83.622785    2.0    5.0        K             BRUNSWICK
# 6957  -94.602991    2.0    3.0        Z              HEAVENER
# 2640 -100.834532    2.0    5.0      NaN  NORTH PLATTE TERMINA
# 3144  -86.327526    2.0    5.0      NaN  INDIANAPOLIS TERMINA
# 2341  -97.381465    2.0    5.0        L            DALLAS SUB
# 9607  -84.542521    2.0    5.0      NaN   CINCINNATI TERMINAL
# 5921  -99.515539    2.0    3.0        Z                LAREDO
# 9059 -104.899184    1.0    1.0        Q                CANYON
# 1531  -73.993500    1.0    1.0        G                NEWARK
#
# [10 rows x 111 columns]

# %%
# Select the desired columns
columns_to_keep = ['railroad', 'incdtno', 'year', 'month', 'day', 'timehr', 'timemin', 'ampm', 'type', 'carshzd', 'station', 'state', 'temp', 'visiblty', 'weather', 'trnspd', 'typspd', 'tons', 'trkclas', 'typtrk', 'loadf1', 'emptyf1', 'cause', 'acctrk', 'acctrkcl', 'highspd', 'accdmg', 'stcnty', 'totinj', 'totkld', 'enghr', 'cdtrhr', 'jointcd', 'region', 'year4', 'county', 'cntycd', 'narr1', 'narr2', 'narr3', 'latitude', 'longitud']
df = df[columns_to_keep]

# Write the updated dataframe to a new CSV file
df.to_csv('RRD_US_combined_cleaned.csv', index=False)

# %%
df.head()
# Out:
#   railroad     incdtno year month day timehr timemin ampm type carshzd  ...  \
# 0     UTAH  UTA022722D   22     3   6     10       0   AM    1       0  ...
# 1       UP   0822MA007   22     8   4      2      10   AM   12       0  ...
# 2       UP   0822MA007   22     8   4      2      10   AM   12       0  ...
# 3       UP   0922NC005   22     9   5     11      12   PM    1       0  ...
# 4       UP   0922NC008   22     9   8     10      30   AM    1       0  ...
#
#   jointcd region year4    county  cntycd  \
# 0       1      7  2022      UTAH      49
# 1       1      5  2022  CRAWFORD      33
# 2       3      5  2022  CRAWFORD      33
# 3       1      7  2022    PLACER      61
# 4       1      7  2022    TULARE     107
#
#                                                narr1  \
# 0  A TRAIN CREW WAS PULLING A CUT OF CARS OUT OF ...
# 1  THE CREW OF TRAIN MNLNP-03 FAILED TO PROTECT A...
# 2  THE CREW OF TRAIN MNLNP-03 FAILED TO PROTECT A...
# 3  MRVNP-05 WAS TRAVELING EAST ON MAIN TRACK 2, W...
# 4  SJVR CREW ON THE LGJGJJ-08, REPORTED THAT THEY...
#
#                                                narr2  \
# 0  IN THE ADJACENT TRACK. THE ENGINEER WAS LOOKIN...
# 1  HE NORTH END OF YARD TRACK 2. THIS UNPROTECTED...
# 2  HE NORTH END OF YARD TRACK 2. THIS UNPROTECTED...
# 3  CK 8 WITH NO AIR SET AND NO THROTTLE ADJUSTMEN...
# 4  THE GOSHEN SIDING. 3 CARS DERAILED DURING A SE...
#
#                                                narr3   latitude    longitud
# 0  AILED TO NOTICE THE SWITCH ON THE RIGHT WAS LI...  40.222489 -111.650240
# 1  WAS PREVIOUSLY SET OUT IN THAT TRACK AT THE SO...  35.430071  -94.344022
# 2  WAS PREVIOUSLY SET OUT IN THAT TRACK AT THE SO...  35.430071  -94.344022
# 3  ECTION, CONDUCTOR FOUND DRAWBAR BETWEEN 12TH A...  39.198577 -120.772514
# 4  NJURIES REPORTED. DURING THE INVESTIGATION, IT...  36.350985 -119.420851
#
# [5 rows x 42 columns]

# %%
# show nulls
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9922 entries, 0 to 9921
# Data columns (total 42 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   railroad  9922 non-null   object
#  1   incdtno   9922 non-null   object
#  2   year      9922 non-null   object
#  3   month     9922 non-null   object
#  4   day       9922 non-null   object
#  5   timehr    9922 non-null   object
#  6   timemin   9922 non-null   object
#  7   ampm      9922 non-null   object
#  8   type      9922 non-null   object
#  9   carshzd   9922 non-null   object
#  10  station   9919 non-null   object
#  11  state     9921 non-null   object
#  12  temp      9922 non-null   object
#  13  visiblty  9918 non-null   float64
#  14  weather   9919 non-null   float64
#  15  trnspd    9922 non-null   object
#  16  typspd    9290 non-null   object
#  17  tons      9922 non-null   object
#  18  trkclas   9912 non-null   object
#  19  typtrk    9914 non-null   float64
#  20  loadf1    9922 non-null   object
#  21  emptyf1   9922 non-null   object
#  22  cause     9921 non-null   object
#  23  acctrk    9914 non-null   float64
#  24  acctrkcl  9915 non-null   object
#  25  highspd   9922 non-null   object
#  26  accdmg    9922 non-null   object
#  27  stcnty    9921 non-null   object
#  28  totinj    9922 non-null   object
#  29  totkld    9922 non-null   object
#  30  enghr     7531 non-null   float64
#  31  cdtrhr    6304 non-null   float64
#  32  jointcd   9922 non-null   object
#  33  region    9921 non-null   object
#  34  year4     9922 non-null   object
#  35  county    9919 non-null   object
#  36  cntycd    9919 non-null   object
#  37  narr1     9921 non-null   object
#  38  narr2     8906 non-null   object
#  39  narr3     5287 non-null   object
#  40  latitude  9922 non-null   float64
#  41  longitud  9922 non-null   float64
# dtypes: float64(8), object(34)
# memory usage: 3.2+ MB

# %%
# Delete rows containing null values for specified columns
df = df.dropna(subset=['state', 'visiblty', 'weather', 'trkclas', 'typtrk', 'cause', 'acctrk', 'acctrkcl', 'stcnty', 'region', 'county', 'cntycd'])

# %%
df.shape
# Out:
# (9904, 42)

# %%
# show nulls
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9904 entries, 0 to 9921
# Data columns (total 42 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   railroad  9904 non-null   object
#  1   incdtno   9904 non-null   object
#  2   year      9904 non-null   object
#  3   month     9904 non-null   object
#  4   day       9904 non-null   object
#  5   timehr    9904 non-null   object
#  6   timemin   9904 non-null   object
#  7   ampm      9904 non-null   object
#  8   type      9904 non-null   object
#  9   carshzd   9904 non-null   object
#  10  station   9904 non-null   object
#  11  state     9904 non-null   object
#  12  temp      9904 non-null   object
#  13  visiblty  9904 non-null   float64
#  14  weather   9904 non-null   float64
#  15  trnspd    9904 non-null   object
#  16  typspd    9279 non-null   object
#  17  tons      9904 non-null   object
#  18  trkclas   9904 non-null   object
#  19  typtrk    9904 non-null   float64
#  20  loadf1    9904 non-null   object
#  21  emptyf1   9904 non-null   object
#  22  cause     9904 non-null   object
#  23  acctrk    9904 non-null   float64
#  24  acctrkcl  9904 non-null   object
#  25  highspd   9904 non-null   object
#  26  accdmg    9904 non-null   object
#  27  stcnty    9904 non-null   object
#  28  totinj    9904 non-null   object
#  29  totkld    9904 non-null   object
#  30  enghr     7522 non-null   float64
#  31  cdtrhr    6297 non-null   float64
#  32  jointcd   9904 non-null   object
#  33  region    9904 non-null   object
#  34  year4     9904 non-null   object
#  35  county    9904 non-null   object
#  36  cntycd    9904 non-null   object
#  37  narr1     9903 non-null   object
#  38  narr2     8891 non-null   object
#  39  narr3     5281 non-null   object
#  40  latitude  9904 non-null   float64
#  41  longitud  9904 non-null   float64
# dtypes: float64(8), object(34)
# memory usage: 3.2+ MB

# %%
# Drop the 'typspd' column
df = df.drop('typspd', axis=1)

# %%
# Convert columns to integers
df['year'] = df['year'].astype(int)
df['month'] = df['month'].astype(int)
df['day'] = df['day'].astype(int)
df['timehr'] = df['timehr'].astype(int)
df['timemin'] = df['timemin'].astype(int)
df['carshzd'] = df['carshzd'].astype(int)
df['temp'] = df['temp'].astype(int)
df['visiblty'] = df['visiblty'].astype(int)
df['trnspd'] = df['trnspd'].astype(int)
df['tons'] = df['tons'].astype(int)

# %%
# Replace 'X' with '1' in the trkclas and acctrkcl columns
df['trkclas'] = df['trkclas'].str.replace('X', '1')
df['acctrkcl'] = df['acctrkcl'].str.replace('X', '1')

# %%
# Delete rows containing 'O' in the trkclas and acctrkcl columns
df = df[~df['trkclas'].str.contains('O')]
df = df[~df['acctrkcl'].str.contains('O')]

# %%
df.trkclas.unique()
# Out:
# array(['1', '2', '3', '4', '7', '5', '8', '6', '9', '0'], dtype=object)

# %%
# Convert more columns to integers
df['trkclas'] = df['trkclas'].astype(int)
df['loadf1'] = df['loadf1'].astype(int)
df['emptyf1'] = df['emptyf1'].astype(int)
df['acctrk'] = df['acctrk'].astype(int)
df['acctrkcl'] = df['acctrkcl'].astype(int)
df['highspd'] = df['highspd'].astype(int)
df['accdmg'] = df['accdmg'].astype(int)
df['year4'] = df['year4'].astype(int)
df['cntycd'] = df['cntycd'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9900 entries, 0 to 9921
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   railroad  9900 non-null   object
#  1   incdtno   9900 non-null   object
#  2   year      9900 non-null   int64
#  3   month     9900 non-null   int64
#  4   day       9900 non-null   int64
#  5   timehr    9900 non-null   int64
#  6   timemin   9900 non-null   int64
#  7   ampm      9900 non-null   object
#  8   type      9900 non-null   object
#  9   carshzd   9900 non-null   int64
#  10  station   9900 non-null   object
#  11  state     9900 non-null   object
#  12  temp      9900 non-null   int64
#  13  visiblty  9900 non-null   int64
#  14  weather   9900 non-null   float64
#  15  trnspd    9900 non-null   int64
#  16  tons      9900 non-null   int64
#  17  trkclas   9900 non-null   int64
#  18  typtrk    9900 non-null   float64
#  19  loadf1    9900 non-null   int64
#  20  emptyf1   9900 non-null   int64
#  21  cause     9900 non-null   object
#  22  acctrk    9900 non-null   int64
#  23  acctrkcl  9900 non-null   int64
#  24  highspd   9900 non-null   int64
#  25  accdmg    9900 non-null   int64
#  26  stcnty    9900 non-null   object
#  27  totinj    9900 non-null   object
#  28  totkld    9900 non-null   object
#  29  enghr     7519 non-null   float64
#  30  cdtrhr    6295 non-null   float64
#  31  jointcd   9900 non-null   object
#  32  region    9900 non-null   object
#  33  year4     9900 non-null   int64
#  34  county    9900 non-null   object
#  35  cntycd    9900 non-null   int64
#  36  narr1     9899 non-null   object
#  37  narr2     8887 non-null   object
#  38  narr3     5278 non-null   object
#  39  latitude  9900 non-null   float64
#  40  longitud  9900 non-null   float64
# dtypes: float64(6), int64(19), object(16)
# memory usage: 3.2+ MB

# %%
df.enghr.unique()
# Out:
# array([ 2., nan,  1.,  5.,  4., 11.,  7.,  8.,  6.,  3.,  9., 10., 13.,
#        32., 12., 14., 25., 16., 22., 15., 21.])

# %%
# Count the number of occurrences of each unique value in the 'enghr' column
enghr_counts = df['enghr'].value_counts()
enghr_counts
# Out:
# 3.0     3362
# 5.0      851
# 2.0      850
# 4.0      825
# 6.0      808
# 7.0      768
# 1.0      699
# 8.0      621
# 9.0      460
# 10.0     379
# 11.0     218
# 12.0      42
# 13.0       4
# 14.0       4
# 16.0       2
# 22.0       2
# 21.0       2
# 32.0       1
# 25.0       1
# 15.0       1
# Name: enghr, dtype: int64

# %%
# Replace 'nan' values in the 'enghr' and 'cdtrhr' columns with the mode from those columns
enghr_mode = df['enghr'].mode()[0]
cdtrhr_mode = df['cdtrhr'].mode()[0]
df['enghr'] = df['enghr'].fillna(enghr_mode)
df['cdtrhr'] = df['cdtrhr'].fillna(cdtrhr_mode)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9900 entries, 0 to 9921
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   railroad  9900 non-null   object
#  1   incdtno   9900 non-null   object
#  2   year      9900 non-null   int64
#  3   month     9900 non-null   int64
#  4   day       9900 non-null   int64
#  5   timehr    9900 non-null   int64
#  6   timemin   9900 non-null   int64
#  7   ampm      9900 non-null   object
#  8   type      9900 non-null   object
#  9   carshzd   9900 non-null   int64
#  10  station   9900 non-null   object
#  11  state     9900 non-null   object
#  12  temp      9900 non-null   int64
#  13  visiblty  9900 non-null   int64
#  14  weather   9900 non-null   float64
#  15  trnspd    9900 non-null   int64
#  16  tons      9900 non-null   int64
#  17  trkclas   9900 non-null   int64
#  18  typtrk    9900 non-null   float64
#  19  loadf1    9900 non-null   int64
#  20  emptyf1   9900 non-null   int64
#  21  cause     9900 non-null   object
#  22  acctrk    9900 non-null   int64
#  23  acctrkcl  9900 non-null   int64
#  24  highspd   9900 non-null   int64
#  25  accdmg    9900 non-null   int64
#  26  stcnty    9900 non-null   object
#  27  totinj    9900 non-null   object
#  28  totkld    9900 non-null   object
#  29  enghr     9900 non-null   float64
#  30  cdtrhr    9900 non-null   float64
#  31  jointcd   9900 non-null   object
#  32  region    9900 non-null   object
#  33  year4     9900 non-null   int64
#  34  county    9900 non-null   object
#  35  cntycd    9900 non-null   int64
#  36  narr1     9899 non-null   object
#  37  narr2     8887 non-null   object
#  38  narr3     5278 non-null   object
#  39  latitude  9900 non-null   float64
#  40  longitud  9900 non-null   float64
# dtypes: float64(6), int64(19), object(16)
# memory usage: 3.2+ MB

# %%
df.enghr.unique()
# Out:
# array([ 2.,  3.,  1.,  5.,  4., 11.,  7.,  8.,  6.,  9., 10., 13., 32.,
#        12., 14., 25., 16., 22., 15., 21.])

# %%
# Convert more columns to integers
df['enghr'] = df['enghr'].astype(int)
df['cdtrhr'] = df['cdtrhr'].astype(int)
df['type'] = df['type'].astype(int)
df['state'] = df['state'].astype(int)
df['totinj'] = df['totinj'].astype(int)
df['totkld'] = df['totkld'].astype(int)
df['jointcd'] = df['jointcd'].astype(int)
df['region'] = df['region'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9900 entries, 0 to 9921
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   railroad  9900 non-null   object
#  1   incdtno   9900 non-null   object
#  2   year      9900 non-null   int64
#  3   month     9900 non-null   int64
#  4   day       9900 non-null   int64
#  5   timehr    9900 non-null   int64
#  6   timemin   9900 non-null   int64
#  7   ampm      9900 non-null   object
#  8   type      9900 non-null   int64
#  9   carshzd   9900 non-null   int64
#  10  station   9900 non-null   object
#  11  state     9900 non-null   int64
#  12  temp      9900 non-null   int64
#  13  visiblty  9900 non-null   int64
#  14  weather   9900 non-null   float64
#  15  trnspd    9900 non-null   int64
#  16  tons      9900 non-null   int64
#  17  trkclas   9900 non-null   int64
#  18  typtrk    9900 non-null   float64
#  19  loadf1    9900 non-null   int64
#  20  emptyf1   9900 non-null   int64
#  21  cause     9900 non-null   object
#  22  acctrk    9900 non-null   int64
#  23  acctrkcl  9900 non-null   int64
#  24  highspd   9900 non-null   int64
#  25  accdmg    9900 non-null   int64
#  26  stcnty    9900 non-null   object
#  27  totinj    9900 non-null   int64
#  28  totkld    9900 non-null   int64
#  29  enghr     9900 non-null   int64
#  30  cdtrhr    9900 non-null   int64
#  31  jointcd   9900 non-null   int64
#  32  region    9900 non-null   int64
#  33  year4     9900 non-null   int64
#  34  county    9900 non-null   object
#  35  cntycd    9900 non-null   int64
#  36  narr1     9899 non-null   object
#  37  narr2     8887 non-null   object
#  38  narr3     5278 non-null   object
#  39  latitude  9900 non-null   float64
#  40  longitud  9900 non-null   float64
# dtypes: float64(4), int64(27), object(10)
# memory usage: 3.2+ MB

# %%
# Extract the first letter from the 'cause' column
df['cause'] = df['cause'].str[0]

# %%
df.cause.unique()
# Out:
# array(['H', 'E', 'M', 'T', 'S'], dtype=object)

# %% [markdown]
# ### What the cause codes mean:
# * H = Human Factor
# * E = Electrical or Mechanical
# * M = Miscellaneous
# * T = Track (rack, roadbed, or structure)
# * S = Signal

# %% [markdown]
# ### Make a clean data function
#
# * see acquire.py file
